# %%
# hello welcome to free python fundamentals and genz AI training session...

# %%
print("hello world")
# Out:
# hello world

# %%
print("welcome to python training fudamentals")
# Out:
# welcome to python training fudamentals

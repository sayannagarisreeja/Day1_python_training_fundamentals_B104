# %%
                             #DAY2_Python_fundamentals_training_session_B104.....

# %%
#introduction to python programming...

# %%
# variables..

# %%
a=10
b=30
c=a+b
print(c)
# Out:
# 40

# %% [raw]
# //variable is a storage location it can hold the values//

# %%
#rules for declaring the python variables.....

# %%
rule1: No Namespaces can be used while declaring the variables...

# %%
first name="Mobile"
print(first name)
# Out:
#   Cell In[7], line 1
#     first name="Mobile"
#           ^
# SyntaxError: invalid syntax

# %%
rule2:a variable name should not start with a letter....

# %%
1name="jupyter"
print(1name)
# Out:
#   Cell In[8], line 1
#     1name="jupyter"
#     ^
# SyntaxError: invalid decimal literal

# %%
rule3:a variable name should not contain any special chracters like @,#,$,&,*...

# %%
name@="laptop"
print(name@)
# Out:
#   Cell In[9], line 2
#     print(name@)
#                ^
# SyntaxError: invalid syntax

# %%
#introduction to datatypes in python......

# %%
strings........(str)
integers......(int)
floating......(float)
lists..........(list)
tuples.........(tuple)
dictionaries....(dict)

# %%
#classification of datatypes.......

# %%
there are two types...
1.mutable datatype..>we can modify the data or edit the date it is flexible in nature..
2.immutable datatype...> we cannot edit the data or modify the data it is fixed in nature..

# %%
#introduction to string datatypes....

strings:collection of characters.
    there are two types..
    1.single quote
    2. double quote

# %%
name='bag' #..single quote...
print(name)
# Out:
# bag

# %%
name="books" #..double quote...
print(name)
# Out:
# books

# %%
#introduction to string methods...

# %%
name="ramya"
type(name)
# Out:
# str

# %%
name1='window'
type(name1)
# Out:
# str

# %%
name="python training fundamentals and Genz AI
